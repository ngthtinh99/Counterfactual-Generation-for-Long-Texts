# %% [markdown]
# Change the direction to CEval

# %%
# %cd /content/drive/MyDrive/Research/CFEs for Long text/Code/CEval
# Out:
# /content/drive/MyDrive/Research/CFEs for Long text/Code/CEval

# %% [markdown]
# Install neccessary libraries

# %%
# %pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Run the Counterfactual metrics evaluation

# %%
# !python eval_counterfactual_metrics.py -task imdb -csv_path results/imdb/lcfe/results.csv
# Out:
# 2025-11-25 21:35:30.174378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764106530.194110    1303 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764106530.200258    1303 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764106530.215679    1303 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# Run the Text quality evaluation

# %%
import os
os.environ["OPENAI_API_KEY"] = "..." # Do not public on GitHub

# %%
# !python eval_text_quality_metrics.py -eval_model gpt -task imdb -csv_path results/imdb/mice/results_toy.csv -temperature 1.0
# Out:
# /content/drive/MyDrive/Research/CFEs for Long text/Code/CEval/eval_text_quality_metrics.py:163: SyntaxWarning: invalid escape sequence '\ '
#   prompt += f"\nIgnore errors related to uppercase and lowercase letters. Please only return a score.\ The score is:"
# grammar_score_gpt_1.0: 3.35
# cohesiveness_score_gpt_1.0: 3.3
# likableness_score_gpt_1.0: 3.2
# fluency_score_gpt_1.0: 3.15

# %% [markdown]
# Thank you for reading this notebook.
